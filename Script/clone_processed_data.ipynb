# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.cloud import bigquery
import pandas as pd
import os

# %%
from google.cloud import bigquery
import os
import pandas as pd

# Thiết lập key và khởi tạo client
keypath = "YOUR_KEY_JSON"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = keypath

client = bigquery.Client()

# Truy vấn dữ liệu
query = """
    SELECT *
    FROM `crawlgame.game_data.cleaned_games`
"""
df = client.query(query).to_dataframe()

# %%
save_path = "/content/drive/MyDrive/SIC_PROJECT/Data/Processed/cleaned_games.parquet"
df.to_parquet(save_path, index=False)
